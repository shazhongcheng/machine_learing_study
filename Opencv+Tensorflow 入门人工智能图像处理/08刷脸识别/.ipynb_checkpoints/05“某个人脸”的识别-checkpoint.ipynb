# %%
# 1 数据yale 2 准备 train label -> train
# 3 cnn 4 检测
import tensorflow as tf
import numpy as np
import scipy.io as sio

f = open('Yale_64x64.mat','rb')
mdict=sio.loadmat(f)
# fea  gnd
train_data = mdict['fea']
train_label = mdict['gnd']

np.random.seed(100)
trainIndex = np.random.choice(len(train_data),len(train_data),replace=False)
testIndex = np.random.choice(len(train_data),64,replace=False)

train_data = train_data[trainIndex]
train_label = train_label[trainIndex]
test_data = train_data[testIndex]
test_label = train_label[testIndex]

# train
train_data = train_data.reshape(train_data.shape[0],64,64,1).astype(np.float32)/255
train_labels_new = np.zeros((165,15))
for i in range(0,165):
    j=int(train_label[i,0]-1)
    train_labels_new[i,j]=1

test_data_input = test_data.reshape(test_data.shape[0],64,64,1).astype(np.float32)/255
test_labels_new = np.zeros((64,15))
for i in range(0,64):
    j=int(test_label[i,0]-1)
    test_labels_new[i,j]=1

# cnn acc tf.nn tf.layer

data_input = tf.placeholder(tf.float32,[None,64,64,1])
label_input = tf.placeholder(tf.float32,[None,15])

layer1 = tf.layers.conv2d(inputs=data_input,filters=32,kernel_size=2,strides=1,padding='SAME',activation=tf.nn.relu)
layer1_pool = tf.layers.max_pooling2d(layer1,pool_size=2,strides=2)
layer2=tf.reshape(layer1_pool,[-1,32*32*32])
layer2_relu=tf.layers.dense(layer2,1024,tf.nn.relu)
output = tf.layers.dense(layer2_relu,15)

loss = tf.losses.softmax_cross_entropy(onehot_labels=label_input,logits=output)
train = tf.train.GradientDescentOptimizer(0.01).minimize(loss)
accuracy=tf.metrics.accuracy(labels=tf.argmax(label_input,axis=1),predictions=tf.argmax(output,axis=1))[1]

init = tf.group(tf.global_variables_initializer(),tf.local_variables_initializer())

# %%
with tf.Session() as sess:
    sess.run(init)
    for i in range(0,200):
        train_data_input = np.array(train_data)
        train_label_input = np.array(train_labels_new)
        sess.run([train,loss],feed_dict={data_input:train_data_input,label_input:train_label_input})
        acc = sess.run(accuracy,feed_dict={data_input:test_data_input,label_input:test_labels_new})
        print('acc:%.2f%'%acc)
# Out:
# acc:0.05
# acc:0.08
# acc:0.14
# acc:0.18
# acc:0.19
# acc:0.20
# acc:0.22
# acc:0.23
# acc:0.23
# acc:0.24
# acc:0.25
# acc:0.26
# acc:0.27
# acc:0.27
# acc:0.28
# acc:0.28
# acc:0.29
# acc:0.29
# acc:0.30
# acc:0.30
# acc:0.31
# acc:0.31
# acc:0.32
# acc:0.33
# acc:0.33
# acc:0.34
# acc:0.34
# acc:0.35
# acc:0.35
# acc:0.35
# acc:0.36
# acc:0.36
# acc:0.37
# acc:0.37
# acc:0.38
# acc:0.38
# acc:0.38
# acc:0.39
# acc:0.39
# acc:0.39
# acc:0.40
# acc:0.40
# acc:0.40
# acc:0.41
# acc:0.41
# acc:0.41
# acc:0.42
# acc:0.42
# acc:0.43
# acc:0.43
# acc:0.43
# acc:0.44
# acc:0.44
# acc:0.45
# acc:0.45
# acc:0.45
# acc:0.46
# acc:0.46
# acc:0.46
# acc:0.47
# acc:0.47
# acc:0.48
# acc:0.48
# acc:0.48
# acc:0.49
# acc:0.49
# acc:0.49
# acc:0.50
# acc:0.50
# acc:0.50
# acc:0.51
# acc:0.51
# acc:0.52
# acc:0.52
# acc:0.52
# acc:0.53
# acc:0.53
# acc:0.53
# acc:0.54
# acc:0.54
# acc:0.54
# acc:0.55
# acc:0.55
# acc:0.55
# acc:0.56
# acc:0.56
# acc:0.56
# acc:0.57
# acc:0.57
# acc:0.57
# acc:0.57
# acc:0.58
# acc:0.58
# acc:0.58
# acc:0.58
# acc:0.59
# acc:0.59
# acc:0.59
# acc:0.59
# acc:0.60
# acc:0.60
# acc:0.60
# acc:0.60
# acc:0.61
# acc:0.61
# acc:0.61
# acc:0.61
# acc:0.61
# acc:0.62
# acc:0.62
# acc:0.62
# acc:0.62
# acc:0.62
# acc:0.63
# acc:0.63
# acc:0.63
# acc:0.63
# acc:0.63
# acc:0.63
# acc:0.64
# acc:0.64
# acc:0.64
# acc:0.64
# acc:0.64
# acc:0.64
# acc:0.65
# acc:0.65
# acc:0.65
# acc:0.65
# acc:0.65
# acc:0.65
# acc:0.66
# acc:0.66
# acc:0.66
# acc:0.66
# acc:0.66
# acc:0.66
# acc:0.67
# acc:0.67
# acc:0.67
# acc:0.67
# acc:0.67
# acc:0.67
# acc:0.68
# acc:0.68
# acc:0.68
# acc:0.68
# acc:0.68
# acc:0.68
# acc:0.68
# acc:0.69
# acc:0.69
# acc:0.69
# acc:0.69
# acc:0.69
# acc:0.69
# acc:0.69
# acc:0.70
# acc:0.70
# acc:0.70
# acc:0.70
# acc:0.70
# acc:0.70
# acc:0.70
# acc:0.71
# acc:0.71
# acc:0.71
# acc:0.71
# acc:0.71
# acc:0.71
# acc:0.71
# acc:0.72
# acc:0.72
# acc:0.72
# acc:0.72
# acc:0.72
# acc:0.72
# acc:0.72
# acc:0.73
# acc:0.73
# acc:0.73
# acc:0.73
# acc:0.73
# acc:0.73
# acc:0.73
# acc:0.73
# acc:0.74
# acc:0.74
# acc:0.74
# acc:0.74
# acc:0.74
# acc:0.74
# acc:0.74
# acc:0.74
# acc:0.75
# acc:0.75
# acc:0.75
# acc:0.75
# acc:0.75
# acc:0.75
