# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties  
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=14)  
# %matplotlib inline

# %%
BATCH_SIZE = 30
#生成数据
seed = 2
rdm = np.random.RandomState(seed)
X=rdm.randn(300,2)

Y_=[int(x0*x0+x1*x1<2) for (x0,x1) in X]
Y_c=[['red' if y else 'blue'] for y in Y_]

X=np.vstack(X).reshape(-1,2)
Y_=np.vstack(Y_).reshape(-1,1)

# print(X)
# print(Y_)
# print(Y_c)
plt.figure()
plt.scatter(X[:,0],X[:,1],c=np.squeeze(Y_c))
# plt.show()

#定义网络
def get_weight(shape,regularizer):
    w=tf.Variable(tf.random_normal(shape),dtype=tf.float32)
    tf.add_to_collection('losses',tf.contrib.layers.l2_regularizer(regularizer)(w))
    return w

def get_bias(shape):
    b=tf.Variable(tf.constant(0.01,shape=shape))
    return b

x=tf.placeholder(tf.float32,shape=(None,2))
y_=tf.placeholder(tf.float32,shape=(None,1))

w1 = get_weight([2,11],0.01)
b1=get_bias([11])
y1=tf.nn.relu(tf.matmul(x,w1)+b1)

w2=get_weight([11,1],0.01)
b2=get_bias([1])
y=tf.matmul(y1,w2)+b2

loss_mse = tf.reduce_mean(tf.square(y-y_))
loss_total = loss_mse+tf.add_n(tf.get_collection('losses'))

train_step = tf.train.AdamOptimizer(0.0001).minimize(loss_mse)

with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    STEPS = 40000
    for i in range(STEPS):
        start=(i*BATCH_SIZE)%300
        end=start+BATCH_SIZE
        sess.run(train_step,feed_dict={x:X[start:end],y_:Y_[start:end]})
        if i%2000==0:
            loss_mse_v = sess.run(loss_mse,feed_dict={x:X,y_:Y_})
            print("After %d steps,loss is: %f"%(i,loss_mse_v))
    xx,yy = np.mgrid[-3:3:.01,-3:3:.01]
    grid = np.c_[xx.ravel(),yy.ravel()]
    
    probs=sess.run(y,feed_dict={x:grid})
    probs=probs.reshape(xx.shape)
    print("w1:\n",sess.run(w1))
    print("b1:\n",sess.run(b1))
    print("w2:\n",sess.run(w2))
    print("b2:\n",sess.run(b2))
plt.figure()    
plt.scatter(X[:,0],X[:,1],c=np.squeeze(Y_c))
plt.contour(xx,yy,probs,levels=[.5])
plt.show()
# Out:
# After 0 steps,loss is: 7.214488
# After 2000 steps,loss is: 2.632314
# After 4000 steps,loss is: 0.908773
# After 6000 steps,loss is: 0.262183
# After 8000 steps,loss is: 0.121275
# After 10000 steps,loss is: 0.091322
# After 12000 steps,loss is: 0.081820
# After 14000 steps,loss is: 0.077579
# After 16000 steps,loss is: 0.075967
# After 18000 steps,loss is: 0.075057
# After 20000 steps,loss is: 0.074397
# After 22000 steps,loss is: 0.073969
# After 24000 steps,loss is: 0.073672
# After 26000 steps,loss is: 0.073461
# After 28000 steps,loss is: 0.073277
# After 30000 steps,loss is: 0.073103
# After 32000 steps,loss is: 0.072949
# After 34000 steps,loss is: 0.072817
# After 36000 steps,loss is: 0.072696
# After 38000 steps,loss is: 0.072552
# w1:
#  [[ 0.22004773  1.103346   -1.5823905   0.17745137  1.1943858   0.19419636
#   -1.1692617  -0.9919011   0.18404359 -0.66902965 -0.7299406 ]
#  [ 0.83833545  1.5234162  -1.4577435   1.3658801   0.9065565   0.7412639
#   -0.6308721   2.6326804  -0.3549897  -1.1556054  -0.66579676]]
# b1:
#  [-0.01633228  0.3391282   0.28635928  0.03625091 -0.5916035   0.05447996
#   0.05784535  0.07137781 -0.33007622 -0.17048779 -0.05523409]
# w2:
#  [[-1.5501822 ]
#  [ 0.16663162]
#  [ 1.2019085 ]
#  [ 0.7247988 ]
#  [-0.6590864 ]
#  [ 1.3898137 ]
#  [-0.5710215 ]
#  [-0.37496266]
#  [-0.9602134 ]
#  [-0.9867908 ]
#  [-1.1453769 ]]
# b2:
#  [0.82153165]

# %%
BATCH_SIZE = 30
#生成数据
seed = 2
rdm = np.random.RandomState(seed)
X=rdm.randn(300,2)

Y_=[int(x0*x0+x1*x1<2) for (x0,x1) in X]
Y_c=[['red' if y else 'blue'] for y in Y_]

X=np.vstack(X).reshape(-1,2)
Y_=np.vstack(Y_).reshape(-1,1)

# print(X)
# print(Y_)
# print(Y_c)
plt.figure()
plt.scatter(X[:,0],X[:,1],c=np.squeeze(Y_c))
# plt.show()

#定义网络
def get_weight(shape,regularizer):
    w=tf.Variable(tf.random_normal(shape),dtype=tf.float32)
    tf.add_to_collection('losses',tf.contrib.layers.l2_regularizer(regularizer)(w))
    return w

def get_bias(shape):
    b=tf.Variable(tf.constant(0.01,shape=shape))
    return b

x=tf.placeholder(tf.float32,shape=(None,2))
y_=tf.placeholder(tf.float32,shape=(None,1))

w1 = get_weight([2,11],0.01)
b1=get_bias([11])
y1=tf.nn.relu(tf.matmul(x,w1)+b1)

w2=get_weight([11,1],0.01)
b2=get_bias([1])
y=tf.matmul(y1,w2)+b2

loss_mse = tf.reduce_mean(tf.square(y-y_))
loss_total = loss_mse+tf.add_n(tf.get_collection('losses'))

train_step = tf.train.AdamOptimizer(0.0001).minimize(loss_total)

with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    STEPS = 40000
    for i in range(STEPS):
        start=(i*BATCH_SIZE)%300
        end=start+BATCH_SIZE
        sess.run(train_step,feed_dict={x:X[start:end],y_:Y_[start:end]})
        if i%2000==0:
            loss_mse_v = sess.run(loss_mse,feed_dict={x:X,y_:Y_})
            print("After %d steps,loss is: %f"%(i,loss_mse_v))
    xx,yy = np.mgrid[-3:3:.01,-3:3:.01]
    grid = np.c_[xx.ravel(),yy.ravel()]
    
    probs=sess.run(y,feed_dict={x:grid})
    probs=probs.reshape(xx.shape)
    print("w1:\n",sess.run(w1))
    print("b1:\n",sess.run(b1))
    print("w2:\n",sess.run(w2))
    print("b2:\n",sess.run(b2))
plt.figure()    
plt.scatter(X[:,0],X[:,1],c=np.squeeze(Y_c))
plt.contour(xx,yy,probs,levels=[.5])
plt.show()
# Out:
# After 0 steps,loss is: 18.460636
# After 2000 steps,loss is: 2.394137
# After 4000 steps,loss is: 0.719720
# After 6000 steps,loss is: 0.392903
# After 8000 steps,loss is: 0.270988
# After 10000 steps,loss is: 0.196463
# After 12000 steps,loss is: 0.160356
# After 14000 steps,loss is: 0.143778
# After 16000 steps,loss is: 0.133790
# After 18000 steps,loss is: 0.127308
# After 20000 steps,loss is: 0.121527
# After 22000 steps,loss is: 0.114562
# After 24000 steps,loss is: 0.105553
# After 26000 steps,loss is: 0.094308
# After 28000 steps,loss is: 0.087112
# After 30000 steps,loss is: 0.084108
# After 32000 steps,loss is: 0.082707
# After 34000 steps,loss is: 0.081719
# After 36000 steps,loss is: 0.081122
# After 38000 steps,loss is: 0.080435
# w1:
#  [[ 1.0654622  -1.1804163  -1.37598     0.85226613  0.13548903  0.92364275
#    0.5508785   0.67984873  0.22322118  1.0679195   0.68470645]
#  [ 0.02985567 -0.44221455 -0.5658426  -0.20000136 -0.533931   -0.49420857
#    0.02993583 -0.56237954 -0.82714885 -0.6290148  -0.0331893 ]]
# b1:
#  [-0.01090184 -0.08104348 -0.11445542  0.10728421  1.0055408   0.05963943
#   0.01975566 -0.05995312 -0.27384236 -0.0032443  -0.16179422]
# w2:
#  [[-1.047681  ]
#  [ 1.0236727 ]
#  [-1.1966777 ]
#  [ 0.7313107 ]
#  [ 0.8392225 ]
#  [-1.5087174 ]
#  [ 0.76785284]
#  [-0.6587311 ]
#  [-0.84116286]
#  [ 1.2317402 ]
#  [ 0.19816124]]
# b2:
#  [0.36333877]
