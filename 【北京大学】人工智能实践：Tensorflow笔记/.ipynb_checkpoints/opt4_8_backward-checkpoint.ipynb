# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import opt4_8_generateds
import opt4_8_forward

# %%
STEPS=40000
BATCH_SIZE=30
LEARNING_RATE_BASE=0.001
LEARNING_RATE_DECAY=0.999
REGULARIZER=0.01

def backward():
    x=tf.placeholder(tf.float32,shape=(None,2))
    y_=tf.placeholder(tf.float32,shape=(None,1))
    X,Y_,Y_c=opt4_8_generateds.generateds()
#     print(X,Y_,Y_c)
    y=opt4_8_forward.forward(x,REGULARIZER)
    global_step=tf.Variable(0,trainable=False)
#     print(y)
    learning_rate = tf.train.exponential_decay(
        LEARNING_RATE_BASE,
        global_step,
        300/BATCH_SIZE,
        LEARNING_RATE_DECAY,
        staircase=True
    )
    loss_mse=tf.reduce_mean(tf.square(y-y_))
    loss_total=loss_mse+tf.add_n(tf.get_collection('losses'))
    
    train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss_total)
    
    with tf.Session() as sess:
        init_op = tf.global_variables_initializer()
        sess.run(init_op)
        STEPS = 40000
        for i in range(STEPS):
            start=(i*BATCH_SIZE)%300
            end=start+BATCH_SIZE
            sess.run(train_step,feed_dict={x:X[start:end],y_:Y_[start:end]})
            if i%2000==0:
                loss_mse_v = sess.run(loss_mse,feed_dict={x:X,y_:Y_})
                print("After %d steps,loss is: %f"%(i,loss_mse_v))
        xx,yy = np.mgrid[-3:3:.01,-3:3:.01]
        grid = np.c_[xx.ravel(),yy.ravel()]

        probs=sess.run(y,feed_dict={x:grid})
        probs=probs.reshape(xx.shape)
    plt.figure()    
    plt.scatter(X[:,0],X[:,1],c=np.squeeze(Y_c))
    plt.contour(xx,yy,probs,levels=[.5])
    plt.show()
backward()
# Out:
# After 0 steps,loss is: 6.749621
# After 2000 steps,loss is: 0.086286
# After 4000 steps,loss is: 0.074945
# After 6000 steps,loss is: 0.073145
# After 8000 steps,loss is: 0.071965
# After 10000 steps,loss is: 0.071554
# After 12000 steps,loss is: 0.070083
# After 14000 steps,loss is: 0.067771
# After 16000 steps,loss is: 0.067311
# After 18000 steps,loss is: 0.066492
# After 20000 steps,loss is: 0.066373
# After 22000 steps,loss is: 0.066495
# After 24000 steps,loss is: 0.066532
# After 26000 steps,loss is: 0.066538
# After 28000 steps,loss is: 0.066541
# After 30000 steps,loss is: 0.066534
# After 32000 steps,loss is: 0.066527
# After 34000 steps,loss is: 0.066521
# After 36000 steps,loss is: 0.066513
# After 38000 steps,loss is: 0.066508
