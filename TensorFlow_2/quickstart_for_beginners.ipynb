# %% [markdown]
# <a href="https://colab.research.google.com/github/shazhongcheng/machine_learing_study/blob/master/TensorFlow_2/quickstart_for_beginners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
